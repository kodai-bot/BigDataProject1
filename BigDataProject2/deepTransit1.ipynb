# %%
# Use Deep Transit pre trained model to detect transits in data. 
import matplotlib 
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import lightkurve as lk
import deep_transit as dt

# %%
model_path = '/home/ckm/model_Kepler.pth'

# %%
lc = lk.search_lightcurve('Kepler-1b', quarter=14, exptime='long').download();
lc = lc[lc.time.value>1340] # To save computating time
lc.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
bboxes = dt.DeepTransit(lc, is_flat=True).transit_detection(model_path)
# Out:
# Loading Model: /home/ckm/model_Kepler.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/jz/szbd_g052yvd9xfkhsf_r_jh0000gn/T/ipykernel_38824/3048463623.py in <module>
# ----> 1 bboxes = dt.DeepTransit(lc, is_flat=True).transit_detection(model_path)
#
# /opt/anaconda3/lib/python3.9/site-packages/deep_transit/dt_lightcurve.py in transit_detection(self, local_model_path, batch_size, confidence_threshold, nms_iou_threshold, device_str, backend)
#     310             from.mge.backend import MegengineBackend
#     311             backend = MegengineBackend()
# --> 312         backend.load_model(local_model_path)
#     313
#     314         real_unit_bboxes = []
#
# /opt/anaconda3/lib/python3.9/site-packages/deep_transit/backend.py in load_model(self, model_path)
#      16     def load_model(self, model_path):
#      17         model = YOLOv3().to(self.device)
# ...
